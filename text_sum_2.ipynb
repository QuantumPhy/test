# %%
import pandas as pd
import re
import numpy as np
import csv
import sys
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2
from gensim.summarization import summarize, keywords,mz_keywords
# Out:
# c:\homeware\anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-23a95dd9d4da> in <module>()
#      11 from sklearn.model_selection import train_test_split
#      12 from sklearn.feature_selection import SelectKBest, chi2
# ---> 13 from gensim.summarization import summarize, keywords,mz_keywords
#
# c:\homeware\anaconda3\lib\site-packages\gensim\__init__.py in <module>()
#       3 """
#       4
# ----> 5 from gensim import parsing, corpora, matutils, interfaces, models, similarities, summarization, utils  # noqa:F401
#       6 import logging
#       7
#
# c:\homeware\anaconda3\lib\site-packages\gensim\corpora\__init__.py in <module>()
# ...

# %%
filepath=r"C:\Users\X172826\Desktop\Input\in\in\PGS_IN_dos.csv"
data=pd.read_csv(filepath,sep=";",encoding="iso-8859-1")

# %%
words = stopwords.words("french")
wordsen=stopwords.words("english")

# %%
data['cleaned_ Incident Description'] = str(data[' Incident Description'].apply(lambda x: " ".\
                                                                            join([i for i in re.sub("[^a-zA-Zéèêçà@.?]", " ", x).split() if i not in words or i not in wordsen]).lower())).correct()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-6e5b71465b29> in <module>()
# ----> 1 data['cleaned_ Incident Description'] = str(data[' Incident Description'].apply(lambda x: " ".                                                                            join([i for i in re.sub("[^a-zA-Zéèêçà@.?]", " ", x).split() if i not in words or i not in wordsen]).lower())).correct()
#
# AttributeError: 'str' object has no attribute 'correct'

# %%
data
# Out:
#         ID Incident  Incident Type  Critical User  001 - Contact Entity  \
# 0      P7IN-0600504       incident         Silver      CORI/COV/FRA/COS
# 1      P7IN-0810098       incident           Gold          LYXR/AIS/EQY
# 2      P7IN-0810098       incident           Gold          LYXR/AIS/EQY
# 3      P7IN-0847708       incident           Gold          OPER/TSU/NEW
# 4      P7IN-0847708       incident           Gold          OPER/TSU/NEW
# 5      P7IN-0856678       incident           Gold      GLFI/NAT/NRG/APF
# 6      P7IN-0858633       incident         Silver              MARK/ATS
# 7      P7IN-0871259       incident            NaN                   NaN
# 8      P7IN-0875012       incident         Silver          DFIN/DTO/TRF
# 9      P7IN-0875994       incident        Premium              DGLE/CDP
# 10     P7IN-0875994       incident        Premium              DGLE/CDP
# 11     P7IN-0895703       incident       Platinum  MARK/FIC/TRD/RAT/EGB
# ...

# %%
from textblob import TextBlob

# %%
from textblob import TextBlob, Word, Blobber
from textblob.classifiers import NaiveBayesClassifier
from textblob.taggers import NLTKTaggerpr

# %%
b = TextBlob("problem")

# %%
b.correct()
# Out:
# TextBlob("probleeeem")

# %%
def blobtostr(x):
    y=TextBlob(x).correct()
    return str(y)

# %%
data['cleaned_ Incident Description'] = data[' Incident Description'].apply(lambda x: " ".\
                                                                            join([i for i in re.sub("[^a-zA-Zéèêçà@.?]", " ", blobtostr(x)).split() if i not in words or i not in wordsen]).lower())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5671cf90ff7a> in <module>()
# ----> 1 data['cleaned_ Incident Description'] = data[' Incident Description'].apply(lambda x: " ".                                                                            join([i for i in re.sub("[^a-zA-Zéèêçà@.?]", " ", blobtostr(x)).split() if i not in words or i not in wordsen]).lower())
#
# c:\homeware\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-5671cf90ff7a> in <lambda>(x)
# ...

# %%
data['word_keywords'] = data['cleaned_ Incident Description'].apply(lambda x: mz_keywords(x,50,scores=False,threshold=0.01))

# %%
data.to_csv("data_12_06_2018_en_fr_2.csv",sep=';',index=False)

# %%
type(data['cleaned_ Incident Description'])
# Out:
# pandas.core.series.Series
